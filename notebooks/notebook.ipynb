# %%
import fastf1 as ff1
from fastf1.events import Session

# %%
session : Session  = ff1.get_session(2021, 'Monaco', 'R')

# %%
session.load()

# %%
session.laps.head(5)
# Out:
#                     Time DriverNumber                LapTime  LapNumber  \
# 0 0 days 00:34:16.815000           33                    NaT        1.0
# 1 0 days 00:35:34.295000           33 0 days 00:01:17.480000        2.0
# 2 0 days 00:36:51.593000           33 0 days 00:01:17.298000        3.0
# 3 0 days 00:38:08.830000           33 0 days 00:01:17.237000        4.0
# 4 0 days 00:39:25.722000           33 0 days 00:01:16.892000        5.0
#
#               PitOutTime PitInTime            Sector1Time  \
# 0 0 days 00:00:04.827000       NaT                    NaT
# 1                    NaT       NaT 0 days 00:00:20.615000
# 2                    NaT       NaT 0 days 00:00:20.460000
# 3                    NaT       NaT 0 days 00:00:20.609000
# 4                    NaT       NaT 0 days 00:00:20.444000
#
#              Sector2Time            Sector3Time     Sector1SessionTime  ...  \
# 0 0 days 00:00:36.535000 0 days 00:00:20.724000                    NaT  ...
# ...

# %%
telemetry = session.laps.pick_driver('HAM').pick_fastest().get_car_data().add_distance()
telemetry.head(5)
# Out:
# /home/fedann/.local/share/virtualenvs/f1data-mongo-test-eSInWmvA/lib/python3.10/site-packages/fastf1/core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time
#                      Date    RPM  Speed  nGear  Throttle  Brake  DRS Source  \
# 0 2021-05-23 14:30:29.241  10664    261      7       100  False    0    car
# 1 2021-05-23 14:30:29.481  10687    263      7       100  False    0    car
# 2 2021-05-23 14:30:29.721  10638    263      7       100  False    0    car
# 3 2021-05-23 14:30:29.961  10691    263      7       100  False    0    car
# 4 2021-05-23 14:30:30.201  10720    263      7       100  False    0    car
#
#                     Time            SessionTime   Distance
# ...
